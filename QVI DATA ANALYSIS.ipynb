# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
QVI = pd.read_csv(r'C:\Users\USER\Downloads\QVI_data.csv')
QVI.sort_values(by = 'DATE')
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 101808          104039  2018-07-01        104  103937        53
# 118872          118107  2018-07-01        118  121300        33
# 221754          226024  2018-07-01        226  226348       114
# 147394          152040  2018-07-01        152  150459        25
# 29702            33140  2018-07-01         33   30342        10
# ...                ...         ...        ...     ...       ...
# 87112            90228  2019-06-30         90   88954        77
# 194066          199122  2019-06-30        199  198088        42
# 194046          199117  2019-06-30        199  198068        77
# 242433          245056  2019-06-30        245  247444        75
# 243910          247060  2019-06-30        247  248955        12
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 101808       RRD Sweet Chilli &  Sour Cream 165g         2        6.0
# ...

# %%
QVI['STORE_NBR'].nunique()
# Out:
# 272

# %%
QVI[QVI['STORE_NBR'] == 1].sort_values(by = 'DATE')
# Out:
#      LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 253            1233  2018-07-01          1     266       110
# 547            1482  2018-07-01          1     563         8
# 466            1414  2018-07-02          1     482        42
# 430            1384  2018-07-02          1     445       106
# 104            1096  2018-07-02          1     110        68
# 406            1366  2018-07-03          1     421        27
# 322            1293  2018-07-04          1     336        46
# 33             1027  2018-07-06          1      34        38
# 60             1057  2018-07-06          1      64        23
# 58             1055  2018-07-08          1      62        43
# 318            1291  2018-07-08          1     331        79
# 571            1504  2018-07-08          1     588        21
# 494            1440  2018-07-08          1     511         8
# 118            1107  2018-07-09          1     125        61
# ...

# %%
QVI
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                 1000  2018-10-17          1       1         5
# 1                 1002  2018-09-16          1       2        58
# 2                 1003  2019-03-07          1       3        52
# 3                 1003  2019-03-08          1       4       106
# 4                 1004  2018-11-02          1       5        96
# ...                ...         ...        ...     ...       ...
# 264829         2370701  2018-12-08         88  240378        24
# 264830         2370751  2018-10-01         88  240394        60
# 264831         2370961  2018-10-24         88  240480        70
# 264832         2370961  2018-10-27         88  240481        65
# 264833         2373711  2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
QVI['DATE'] = pd.to_datetime(QVI['DATE'])

# %%
QVI['DAY'] = QVI['DATE'].dt.day
QVI['MONTH'] = QVI['DATE'].dt.month
QVI['YEAR'] = QVI['DATE'].dt.year
QVI
# Out:
#         LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                 1000 2018-10-17          1       1         5
# 1                 1002 2018-09-16          1       2        58
# 2                 1003 2019-03-07          1       3        52
# 3                 1003 2019-03-08          1       4       106
# 4                 1004 2018-11-02          1       5        96
# ...                ...        ...        ...     ...       ...
# 264829         2370701 2018-12-08         88  240378        24
# 264830         2370751 2018-10-01         88  240394        60
# 264831         2370961 2018-10-24         88  240480        70
# 264832         2370961 2018-10-27         88  240481        65
# 264833         2373711 2018-12-14         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
pd.options.display.max_rows = 10000

# %%
QVI.isna().sum()
# Out:
# LYLTY_CARD_NBR      0
# DATE                0
# STORE_NBR           0
# TXN_ID              0
# PROD_NBR            0
# PROD_NAME           0
# PROD_QTY            0
# TOT_SALES           0
# PACK_SIZE           0
# BRAND               0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# DAY                 0
# MONTH               0
# YEAR                0
# dtype: int64

# %%
QVI.head(100).sort_values(by = 'DATE')
# Out:
#     LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 33            1027 2018-07-06          1      34        38
# 60            1057 2018-07-06          1      64        23
# 58            1055 2018-07-08          1      62        43
# 75            1068 2018-07-21          1      79        73
# 41            1042 2018-07-21          1      45        94
# 93            1087 2018-07-25          1      98        90
# 79            1072 2018-07-27          1      84        73
# 11            1011 2018-07-29          1      12        84
# 48            1048 2018-08-02          1      52         1
# 54            1053 2018-08-07          1      58        47
# 34            1027 2018-08-13          1      35        16
# 25            1020 2018-08-16          1      26        19
# 21            1018 2018-09-03          1      22         3
# 61            1057 2018-09-03          1      65        59
# 53            1052 2018-09-05          1      57        44
# ...

# %%
MONTHLY_SALES = QVI.groupby(['YEAR', 'MONTH'])['TOT_SALES'].sum().reset_index()
MONTHLY_SALES
# Out:
#     YEAR  MONTH  TOT_SALES
# 0   2018      7  165275.30
# 1   2018      8  158081.05
# 2   2018      9  160522.00
# 3   2018     10  164415.70
# 4   2018     11  160233.70
# 5   2018     12  167913.40
# 6   2019      1  162642.30
# 7   2019      2  150665.00
# 8   2019      3  166265.20
# 9   2019      4  159845.10
# 10  2019      5  156717.65
# 11  2019      6  160538.60

# %%
QVI.STORE_NBR.nunique()
# Out:
# 272

# %% [markdown]
# # DECEMBER, 2018 HAD THE MOST SALES

# %%
MAX_SALES_MONTH = MONTHLY_SALES.loc[MONTHLY_SALES['TOT_SALES'].idxmax()]
MAX_SALES_MONTH
# Out:
# YEAR           2018.0
# MONTH            12.0
# TOT_SALES    167913.4
# Name: 5, dtype: float64

# %%
MON_SALES_18 = MONTHLY_SALES.loc[MONTHLY_SALES['YEAR'] == 2018]
MON_SALES_18.head()
# Out:
#    YEAR  MONTH  TOT_SALES
# 0  2018      7  165275.30
# 1  2018      8  158081.05
# 2  2018      9  160522.00
# 3  2018     10  164415.70
# 4  2018     11  160233.70

# %%
MON_SALES_19 = MONTHLY_SALES.loc[MONTHLY_SALES['YEAR'] == 2019]
MON_SALES_19.head()
# Out:
#     YEAR  MONTH  TOT_SALES
# 6   2019      1  162642.30
# 7   2019      2  150665.00
# 8   2019      3  166265.20
# 9   2019      4  159845.10
# 10  2019      5  156717.65

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 7))
ax[0].bar(MON_SALES_18['MONTH'], MON_SALES_18['TOT_SALES'], color = 'black')
ax[1].bar(MON_SALES_19['MONTH'], MON_SALES_19['TOT_SALES'], color = 'black')

ax[0].set(title = '2018 MONTHLY SALES')
ax[1].set(title = '2019 MONTHLY SALES')

ax[0].set(xlabel = 'MONTH')
ax[0].set(ylabel = 'PRICE')

ax[1].set(xlabel = 'MONTH')
ax[1].set(ylabel = 'PRICE')
# Out:
# [Text(0, 0.5, 'PRICE')]

# %% [markdown]
#    #    GRAPH OF THE MONTHLY SALES OF THE YEAR 2018 AND 2019

# %%
QVI.sample(5)
# Out:
#         LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 206764          212098 2019-01-17        212  211040        90
# 80935            83099 2018-12-24         83   82655       110
# 228486          230186 2019-05-09        230  233201        18
# 62547            67009 2018-09-07         67   63879        41
# 125021          123372 2019-06-05        123  127609        68
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 206764    Tostitos Smoked     Chipotle 175g         2        8.8        175
# 80935        WW Original Corn    Chips 200g         2        3.8        200
# 228486       Cheetos Chs & Bacon Balls 190g         2        6.6        190
# 62547              Doritos Salsa Mild  300g         2        5.2        300
# 125021  Pringles Chicken    Salt Crips 134g         2        7.4        134
#
#              BRAND              LIFESTAGE PREMIUM_CUSTOMER  DAY  MONTH  YEAR
# ...

# %%
STORE_SALES_COUNT = QVI.groupby(['STORE_NBR'])['TOT_SALES'].count().reset_index()
STORE_SALES_COUNT
# Out:
#      STORE_NBR  TOT_SALES
# 0            1        573
# 1            2        506
# 2            3       1502
# 3            4       1678
# 4            5       1361
# 5            6        530
# 6            7       1482
# 7            8        520
# 8            9        659
# 9           10       1467
# 10          11          2
# 11          12        573
# 12          13       1564
# 13          14         66
# 14          15       1377
# 15          16        442
# 16          17        553
# 17          18        581
# 18          19       1153
# 19          20        559
# 20          21        600
# 21          22        582
# 22          23       1490
# 23          24       1348
# 24          25        601
# 25          26       1640
# 26          27        588
# 27          28       1357
# 28          29        551
# 29          30       1471
# 30          31          2
# 31          32       1436
# 32          33       1596
# 33          34        512
# ...

# %%
STORE_SALES_SUM = QVI.groupby(['STORE_NBR'])['TOT_SALES'].sum().reset_index()
STORE_SALES_SUM
# Out:
#      STORE_NBR  TOT_SALES
# 0            1    2393.60
# 1            2    2005.80
# 2            3   12802.45
# 3            4   14647.65
# 4            5    9500.80
# 5            6    2684.90
# 6            7   12486.90
# 7            8    4499.20
# 8            9    4012.40
# 9           10   10302.30
# 10          11       6.70
# 11          12    5009.90
# 12          13   10686.50
# 13          14     410.70
# 14          15    9486.05
# 15          16    1632.10
# 16          17    4636.60
# 17          18    3269.70
# 18          19    8972.90
# 19          20    2519.25
# 20          21    5154.90
# 21          22    3689.40
# 22          23   10305.80
# 23          24    9230.00
# 24          25    5297.65
# 25          26   14469.30
# 26          27    5120.70
# 27          28    9374.35
# 28          29    4697.50
# 29          30   10359.50
# 30          31      14.80
# 31          32    9983.50
# 32          33   11164.00
# 33          34    4266.20
# ...

# %% [markdown]
# # STORE WITH THE MOST SALES

# %%
STORE_SALES_SUM.loc[STORE_SALES_SUM['TOT_SALES'] == STORE_SALES_SUM['TOT_SALES'].max()]
# Out:
#      STORE_NBR  TOT_SALES
# 225        226   17605.45

# %%
fig, ax = plt.subplots(figsize = (15, 7))
plt.bar(STORE_SALES_SUM['STORE_NBR'], STORE_SALES_SUM['TOT_SALES'], color = 'black') 
plt.title('GRAPH OF THE SALES')
plt.show()
